# %%
import agrow as ar
import numpy as np

# %%
print(ar.int8)
# Out:
# <class 'agrow.core.biult_ins.int8'>

# %%
arr = np.array([1, 3.4, 5, 3.], dtype=ar.int8)

# %%
arr
# Out:
# array([1, 3.4, 5, 3.0], dtype=object)
